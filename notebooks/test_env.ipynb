# %%
import sys
from pathlib import Path

repo_root = Path.cwd().parent  # go up from notebooks/ to repo/
sys.path.insert(0, str(repo_root / "src"))

print("repo_root:", repo_root)
print("src exists?:", (repo_root / "src").exists())
# Out:
# repo_root: /Users/elyssephillips/projects/nuclei-tracking-pipeline
# src exists?: True

# %%
from nuclei_tracking.utils import hello
hello("elysse")
# Out:
# 'hello, elysse'

# %%
from pathlib import Path
Path.cwd()
# Out:
# PosixPath('/Users/elyssephillips/projects/nuclei-tracking-pipeline')

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd() / "src"))
from nuclei_tracking.utils import hello
hello("elysse")
# Out:
# 'hello, elysse'
